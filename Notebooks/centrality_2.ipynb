# %%
import networkx as nx
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('ca-HepTh.csv')

# %%
nodes = np.concatenate((dataset['Source'].unique(), dataset['Target'].unique()))
#edges = dataset.iloc[:, :].values

# %%
nodes = np.unique(nodes)

# %%
for j in range(0, len(nodes)):
    dataset = dataset.replace(nodes[j], j)
    #replacer.append((int(temp_node[j]), int(j)))
    #print(replacer)

# %%
edges = dataset.iloc[:, :].values

# %%
nodes = np.arange(0, len(nodes))

# %%
G = nx.Graph()
G.add_nodes_from(nodes)
G.add_edges_from(edges)
G = G.to_undirected()

# %%
bet_cen = nx.algorithms.centrality.betweenness_centrality(G)

# %%
print(bet_cen)
# Out:
# {0: 0.0, 1: 0.0, 2: 0.0005820011580890311, 3: 0.0001771023988597854, 4: 0.0, 5: 2.0507457024060374e-08, 6: 0.0, 7: 0.0, 8: 0.0, 9: 0.0, 10: 0.0, 11: 0.0, 12: 0.009424558795271397, 13: 0.0009497709477993483, 14: 0.0, 15: 0.0, 16: 0.0006901207717882418, 17: 1.0253728512030187e-08, 18: 0.0005925333071262637, 19: 0.0001771023988597854, 20: 0.0, 21: 0.0008384075954564124, 22: 0.0, 23: 0.0, 24: 0.0, 25: 0.0, 26: 4.554290205906528e-05, 27: 5.141846969541601e-05, 28: 9.455702002479758e-05, 29: 0.0, 30: 0.0, 31: 0.0, 32: 2.0507457024060374e-08, 33: 0.000730660330707392, 34: 0.0, 35: 0.0, 36: 6.738058059919883e-05, 37: 0.0, 38: 0.00016607802946054978, 39: 0.0, 40: 0.0, 41: 0.0, 42: 0.00010000148218067445, 43: 0.0008724443792752743, 44: 0.0, 45: 0.0, 46: 0.0, 47: 0.0017445850404774188, 48: 0.0, 49: 0.0, 50: 0.0, 51: 0.0004424586390226146, 52: 0.00020451302435564096, 53: 0.0, 54: 0.0, 55: 0.0003721855503962507, 56: 3.5163400411714035e-05, 57: 3.076118553609056e-08, 58: 0.0, 59: 0.0, 60: 0.0, 61: 0.0, 62: 5.476238832558675e-08, 63: 0.0, 64: 0.0, 65: 0.0, 66: 0.0004486950979783195, 67: 0.0, 68: 0.0012388759862805112, 69: 0.0, 70: 0.0, 71: 0.0, 72: 0.0003541842902625467, 73: 0.0024246674276147107, 74: 0.0, 75: 0.0014251386074812242, 76: 0.0004927941401321439, 77: 0.0, 78: 0.00034221942243357315, 79: 0.0, 80: 0.001334292222833937, 81: 0.00037760728038973857, 82: 0.0, 83: 0.0004423309905728973, 84: 0.0, 85: 0.0, 86: 0.0, 87: 0.0, 88: 0.0, 89: 2.3503306384788713e-05, 90: 3.4468549727237705e-05, 91: 0.0, 92: 1.5560068110998653e-05, 93: 0.0004066414178953028, 94: 0.0030072575998053514, 95: 0.0, 96: 0.0008852966660001743, 97: 0.0, 98: 0.00035416378280552266, 99: 0.009664466050754784, 100: 0.0, 101: 0.0, 102: 0.0, 103: 0.0, 104: 1.1637044388835165e-05, 105: 0.0, 106: 0.0, 107: 0.0, 108: 0.0025409118922531206, 109: 0.00013570343091875628, 110: 0.0, 111: 0.0, 112: 0.0, 113: 0.0036112442523230596, 114: 0.0, 115: 0.0010031738243748256, 116: 0.0001771023988597854, 117: 0.0, 118: 0.0, 119: 0.0, 120: 0.0, 121: 0.0004023637551406869, 122: 0.0, 123: 0.0, 124: 0.0, 125: 0.0, 126: 0.0, 127: 0.0, 128: 8.711887128048556e-05, 129: 4.6717845217897096e-05, 130: 0.0, 131: 4.164704373861092e-06, 132: 0.0009388206248632199, 133: 0.0, 134: 0.0, 135: 0.00035416378280552266, 136: 3.303223212547943e-05, 137: 0.00013749126947380628, 138: 0.0, 139: 0.0003101778109090802, 140: 0.0, 141: 0.0006337632019467883, 142: 0.000663949738568055, 143: 0.0, 144: 0.0004615501623608984, 145: 0.00037356894183994876, 146: 0.00023855931819966213, 147: 8.827299622169995e-05, 148: 0.0, 149: 0.0, 150: 0.0, 151: 0.0, 152: 0.005187521859110302, 153: 0.0, 154: 5.042848572111735e-05, 155: 0.0, 156: 0.0, 157: 0.0005772366475381876, 158: 0.003715198503535935, 159: 0.0004093166643121811, 160: 0.0, 161: 0.00010178224515788, 162: 0.0005229878151310048, 163: 0.0, 164: 0.0001771023988597854, 165: 0.0012616634336314117, 166: 0.0, 167: 0.0006813092982760853, 168: 0.0005492415926947112, 169: 0.0, 170: 0.0, 171: 0.0032213258934072116, 172: 0.0, 173: 0.0, 174: 0.00010589046123677263, 175: 0.0, 176: 0.0, 177: 0.0, 178: 0.0010792306608952444, 179: 0.0014538091603736893, 180: 0.0, 181: 0.00043705619948466914, 182: 4.536757765794107e-05, 183: 6.6691484951057e-06, 184: 2.951475783641568e-06, 185: 0.0004376582853478134, 186: 0.0, 187: 0.0, 188: 0.0015039885984456495, 189: 0.0007826961454788873, 190: 0.0, 191: 0.0009652096183198165, 192: 0.0, 193: 0.0, 194: 1.7763596770998153e-05, 195: 0.0001754995365043884, 196: 0.0, 197: 0.0, 198: 0.0002812025624429618, 199: 0.0, 200: 0.0, 201: 0.0, 202: 0.0, 203: 0.00020240461280945896, 204: 0.0, 205: 0.0, 206: 0.0, 207: 0.0001771023988597854, 208: 0.0, 209: 0.002072495734277861, 210: 0.0036400064175970224, 211: 0.0, 212: 0.00013683751442628068, 213: 0.00017091734598838817, 214: 0.0, 215: 0.0, 216: 3.4730587884863845e-05, 217: 0.00018815263395786848, 218: 0.0005790879869124552, 219: 0.0, 220: 0.00012629581277662154, 221: 0.0, 222: 0.016695725236123882, 223: 1.3159765378415888e-07 ...

# %%
import operator

# %%
max(bet_cen.items(), key=operator.itemgetter(1))
# Out:
# (6293, 0.02370303612662779)

# %%
#export_csv = dataset.to_csv ('ca-HepTh-new.csv', index = None, header=False)

# %%
G.number_of_edges()
# Out:
# 25998

# %%
#nx.write_edgelist(G, 'ca-HepTh-new.csv')

# %%
dense_nodes = []
f = open("densest-ca-HepTh-new.txt", "r")
dense_nodes = list(map(int, f.readlines()))
f.close()

sorted_bet_cen = sorted(bet_cen.items(), key=operator.itemgetter(1))

sorted_bet_cen.reverse()

hits = 0
total = len(dense_nodes)
consider = sorted_bet_cen[:total]

for i in range(total):
    if consider[i][0] in dense_nodes:
        hits += 1
        
(hits / total) * 100
# Out:
# 0.0

# %%
hit_nodes = []
deg_cen = G.degree(nodes)
sorted_deg_cen = sorted(deg_cen.items(), key=operator.itemgetter(1))

sorted_deg_cen.reverse()

hits = 0
total = len(dense_nodes)
consider = sorted_deg_cen[:total]

for i in range(total):
    if consider[i][0] in dense_nodes:
        hits += 1
        hit_nodes.append(consider[i][0])
        
(hits / total) * 100
# Out:
# 3.125

# %%
dense_deg = G.degree(dense_nodes)

# %%
exact_nodes = [63, 744, 862, 899, 939, 949, 1542, 1676, 2296, 2362, 2660, 2777, 3445, 3554, 3615, 3789, 4668, 5310, 5325, 5403, 5483, 5735, 6106, 6583, 6787, 6872, 6985, 7111, 7362, 7450, 7699, 7950]

# %%
hit_nodes = []

sorted_bet_cen = sorted(bet_cen.items(), key=operator.itemgetter(1))

sorted_bet_cen.reverse()

hits = 0
total = len(exact_nodes)
consider = sorted_bet_cen[:total]

for i in range(total):
    if consider[i][0] in exact_nodes:
        hits += 1
        hit_nodes.append(consider[i][0])
        
print((hits / total) * 100)

hit_nodes = []
deg = G.degree(nodes)
sorted_deg = sorted(deg.items(), key=operator.itemgetter(1))

sorted_deg.reverse()

hits = 0
total = len(exact_nodes)
consider = sorted_deg[:total]

for i in range(total):
    if consider[i][0] in exact_nodes:
        hits += 1
        hit_nodes.append(consider[i][0])
        
print((hits / total) * 100)

hit_nodes = []
clo_cen = nx.algorithms.centrality.closeness_centrality(G)
sorted_clo_cen = sorted(clo_cen.items(), key=operator.itemgetter(1))

sorted_clo_cen.reverse()

hits = 0
total = len(exact_nodes)
consider = sorted_clo_cen[:total]

for i in range(total):
    if consider[i][0] in exact_nodes:
        hits += 1
        hit_nodes.append(consider[i][0])
        
print((hits / total) * 100)
# Out:
# 0.0
# 3.125
# 0.0

# %%
G.remove_edges_from(G.selfloop_edges())
cores = nx.algorithms.core.core_number(G)

k_max = max(cores.items(), key=operator.itemgetter(1))[1]
k_min = min(cores.items(), key=operator.itemgetter(1))[1]

densities = []
for i in range(k_min, k_max + 1):
    H = nx.algorithms.core.k_core(G, k=i)
    densities.append(H.number_of_edges() / H.number_of_nodes())
    
densities
# Out:
# [2.6296446289359117,
#  2.6301772151898732,
#  3.1535733053074093,
#  3.8364694471387004,
#  4.606572481572481,
#  5.261673151750973,
#  6.019930675909879,
#  6.894648829431438,
#  7.849122807017544,
#  11.30188679245283,
#  12.010416666666666,
#  12.010416666666666,
#  12.010416666666666,
#  12.010416666666666,
#  12.010416666666666,
#  12.010416666666666,
#  12.010416666666666,
#  12.010416666666666,
#  12.010416666666666,
#  12.753246753246753,
#  12.753246753246753,
#  13.785714285714286,
#  13.785714285714286,
#  13.785714285714286,
#  15.5,
#  15.5,
#  15.5,
#  15.5,
#  15.5,
#  15.5,
#  15.5,
#  15.5]
